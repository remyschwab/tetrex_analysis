# %%
# %load_ext autoreload
# %autoreload 2

# %%
from analysis_lib import *

# %% [markdown]
# ## Reviewer 2: Prosite Pattern Length Analysis

# %%
patterns = pd.read_csv("/Users/rschwab/repos/tetrex_analysis/data/PATTERNS/prosite_patterns.tsv", sep="\t")

# %%
patterns.shape
# Out:
# (1311, 3)

# %%
patterns["LENGTH"] = pd.Series([(pattern.count('-')+1) for pattern in patterns.iloc[:,2]])
plt = patterns["LENGTH"].plot.hist()
plt.axvline(6, color='k', linestyle='--')
plt.set_xlabel("Pattern Lengths")
plt.set_title("Distribution of 1311 Prosite Pattern Lengths")
# Out:
# Text(0.5, 1.0, 'Distribution of 1311 Prosite Pattern Lengths')

# %%
# patterns[patterns["LENGTH"] < 6].to_csv("/Users/rschwab/repos/tetrex_analysis/data/RESULTS/small_patterns.csv")
patterns[patterns["LENGTH"] < 7].shape
# Out:
# (30, 4)
